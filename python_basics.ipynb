# %% [markdown]
# <a href="https://colab.research.google.com/github/jayakrishnan004/DSA_Practice/blob/main/python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# variable - a simpolic name that act as a pointer or reference to an object stored in computer memory.
# In python, declaration of a variable is not mandatory before using it. Python
# creates the variable automatically the moment you first assign a value to it.
# Python automatically detects datatypes and this is called dynamic typing. Python is case sensitive, it support multiple assignments, chained assignments.

# %%
cost = 100.89
name = "JK"
rating = 4.5
print(name)
# print("Cost of the toy is Rs.", cost)
# print(f"cost of the toy is Rs.{cost}")
print(f"cost of the toy is Rs.{cost:.1f}")
# Out:
# JK
# cost of the toy is Rs.100.9

# %% [markdown]
# f string is a modern preferred way to format strings in python, Prefixed with "f" or "F". It allows you to embedd variables in expression and functions directly inside curly braces {}

# %%
# Initialize the variables name with Alice, age with 23, and score with 82. Finally display the statement alice with age 23 secured 82 marks in English.

name = "Alice"
age = 23
score = 82
print(f"{name} with age {age} secured a score of {score} marks in English.")

# to get the data type of a variable
print(type(name))
# Out:
# Alice with age 23 secured a score of 82 marks in English.
# <class 'str'>

# %%
n = 2+3j
print(type(n))  # To get the data type of a variable
# Out:
# <class 'str'>
# <class 'complex'>

# %%
# Trying end and sep
print("01", "09", "2026")
# changing sep to hyphen
print("01", "09", "2026", sep="-")
# removing sep completely
print("01", "09", "2026", sep = " ")
print("py", "th", "on", sep = "")


print("welcome to the world of python", end = '!')
# Out:
# 01 09 2026
# 01-09-2026
# 01 09 2026
# python
# welcome to the world of python!

# %%
# chain rule
x=y=z=1
print(x)
print(y)
print("\n")
print(z)
# Out:
# 1
# 1
#
#
# 1

# %%
# # Typecasting
# d = 10
# x = float(d)
# print(x)
# print(type(x))
# Out:
# 10.0
# <class 'float'>

# %% [markdown]
# write the python snippet to accept the cost of a toy car and a pencil box. Finally compute the total amount to be paid to that shop.

# %%
c1 = float(input("Enter the cost of toy car :"))
c2 = float(input("Enter the cost of the pencil box :"))
Total = c1 + c2
T = print(f"The total amount to be paid in the shop is Rs. {Total}")
# Out:
# Enter the cost of toy car :30
# Enter the cost of the pencil box :20
# The total amount to be paid in the shop is Rs. 50.0

# %%
# print("python\t"*3)
print("python\n"*3)
# Out:
# python
# python
# python

# %%
course = "python programming"
print(course[-2])
print(course[2])
print(len(course))
print(course[-len(course)])
print(course[0:4])
print(course[:6])
print(course[1:18:2])

print(course.capitalize())
print(course.lower())
print(course.upper())
print(course.swapcase())
# Out:
# n
# t
# 18
# p
# pyth
# python
# yhnpormig
# Python programming
# python programming
# PYTHON PROGRAMMING
# PYTHON PROGRAMMING

# %%
#  Arithmetic operators
num1 = 20
num2 = 11
print(num1+num2)
print(num1-num2)
print(num1*num2)
print(num1/num2)
print(num1%num2)
print(num1**num2)
print(num1//num2)
# Out:
# 31
# 9
# 220
# 1.8181818181818181
# 9
# 204800000000000
# 1

# %%
#  floor(x) rounds a number down to the greatest integer less <= x
ceil(x) rounds a number up to the smallest integer >= x
import math
num = 4.5
p = print(math.floor(num))
p = print(math.ceil(num))
# Out:
# 4
# 5

# %% [markdown]
# is and is not both are identity operators.
